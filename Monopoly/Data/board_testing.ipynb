# %%
# Import statements
import pandas as pd

# %%
# Create Monopoly dataframe
df = pd.read_csv('newboard.csv')

df
# Out:
#                      Name     Space      Color  Position(X)  Position(Y)  \
# 0                      Go        Go       None            0            0
# 1    Mediterranean Avenue    Street      Brown            0            1
# 2         Community Chest     Chest       None            0            2
# 3           Baltic Avenue    Street      Brown            0            3
# 4              Income Tax       Tax       None            0            4
# 5        Reading Railroad  Railroad       None            0            5
# 6         Oriental Avenue    Street  LightBlue            0            6
# 7                  Chance    Chance       None            0            7
# 8          Vermont Avenue    Street  LightBlue            0            8
# 9      Connecticut Avenue    Street  LightBlue            0            9
# 10                   Jail      Jail       None            1            0
# 11      St. Charles Place    Street       Pink            1            1
# ...

# %%
# Get unique tile types
tuple(df['Space'].unique())
# Out:
# ('Go',
#  'Street',
#  'Chest',
#  'Tax',
#  'Railroad',
#  'Chance',
#  'Jail',
#  'Utility',
#  'Parking',
#  'GoToJail')

# %%
# Get unique tile colors
tuple(df['Color'].unique())
# Out:
# ('None',
#  'Brown',
#  'LightBlue',
#  'Pink',
#  'Orange',
#  'Red',
#  'Yellow',
#  'Green',
#  'Blue')
